# %%
import requests
from IPython.display import Image, display, clear_output
import time
from urllib.parse import urlencode
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %matplotlib inline

# %%
# Function to set motors
def set_motors(jetbot_ip, left_speed, right_speed):
    params = {'left': left_speed, 'right': right_speed}
    url = f'http://{jetbot_ip}:8080/set_motors?{urlencode(params)}'
    response = requests.get(url)
    if response.status_code == 200:
        print("Motors set successfully")
    else:
        print("Failed to set motors")

# %%
# Function to execute stop command
def stop_robot(jetbot_ip):
    url = f'http://{jetbot_ip}:8080/stop'
    response = requests.get(url)
    if response.status_code == 200:
        print("Stop command executed successfully")
    else:
        print("Failed to execute stop command")

# %%
# A function that continuously streams video and allows saving images on pressing 's' and quitting on 'q'
def take_pictures_loop(jetbot_ip):
    folder = 'training_images'
    os.makedirs(folder, exist_ok=True)  # Create the folder if it doesn't exist

    url = f'http://{jetbot_ip}:8080/camera'

    while True:
        response = requests.get(url)
        img_array = np.frombuffer(response.content, dtype=np.uint8)
        image = cv2.imdecode(img_array, cv2.IMREAD_COLOR)

        if image is not None:
            cv2.imshow("JetBot Camera - Press 's' to save, 'q' to quit", image)

            key = cv2.waitKey(1) & 0xFF
            if key == ord('s'):  # Save image on pressing 's'
                # Count the number of files in the folder
                file_count = len([name for name in os.listdir(folder) if os.path.isfile(os.path.join(folder, name))])

                # Generate the new file name
                new_file_name = f'img{file_count + 1}.jpg'
                new_file_path = os.path.join(folder, new_file_name)

                cv2.imwrite(new_file_path, image)
                print(f"Image saved as {new_file_path}")
            elif key == ord('q'):  # Quit on pressing 'q'
                break
        else:
            print("Failed to capture image")

    cv2.destroyAllWindows()

# %%
# # from ultralytics import YOLO

# # Load the YOLOv8 model
# model = YOLO("yolov8n.pt")  # You can replace "yolov8n.pt" with other YOLOv8 variants like "yolov8s.pt"

# # Train the model on the dataset
# model.train(data="datasets/data.yaml", epochs=50, imgsz=224)

# # Save the trained model
# model.save("models/yolov8n_trained.pt")

# %%
# Function to do object detection on all images in a folder and plot results
def detect_objects_in_folder(folder_path):
    images = []
    titles = []
    model = YOLO('models/yolov8n_trained.pt')  # Load the YOLOv8 model

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):  # Check for image files
            image_path = os.path.join(folder_path, filename)
            print(f"Processing {image_path}...")

            # Load the image
            image = cv2.imread(image_path)

            labels = ['robot', 'target']

            # Perform object detection
            results = model.predict(source=image, conf=0.25, save=False)

            # Annotate the image with detections and calculate angles
            bounding_boxes = []
            for result in results:
                boxes = result.boxes.xyxy  # Bounding boxes
                confidences = result.boxes.conf  # Confidence scores
                class_ids = result.boxes.cls  # Class IDs

                for box, conf, class_id in zip(boxes, confidences, class_ids):
                    x1, y1, x2, y2 = map(int, box)
                    label = f"{labels[int(class_id)]}: {conf:.2f}"   
                    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

                    # Add bounding box for angle calculation
                    bounding_boxes.append((x1, y1, x2, y2))

            # Calculate angles for detected objects
            angles = calculate_object_angles(bounding_boxes, image_width=image.shape[1], image_height=image.shape[0], fov_deg=160)
            print(f"Angles for {filename}: {angles}")

            # Convert BGR to RGB for matplotlib
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            images.append(image_rgb)
            titles.append(filename)

    # Plot the images with detections
    num_images = len(images)
    cols = 3
    rows = (num_images + cols - 1) // cols  # Calculate rows needed

    fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows))
    axes = axes.flatten()

    for i, ax in enumerate(axes):
        if i < num_images:
            ax.imshow(images[i])
            ax.set_title(titles[i])
            ax.axis('off')
        else:
            ax.axis('off')  # Hide unused subplots

    plt.tight_layout()
    plt.show()

# %%
def print_camera_yolo(jetbot_ip):
    # Load the trained YOLOv8 model
    model = YOLO("models/yolov8n_trained.pt")  # Load the trained model

    url = f'http://{jetbot_ip}:8080/camera'
    
    while True:
        response = requests.get(url)
        img_array = np.frombuffer(response.content, dtype=np.uint8)
        image = cv2.imdecode(img_array, cv2.IMREAD_COLOR)

        if image is not None:
            # Run YOLO detection (pass BGR image directly)
            results = model.predict(image, verbose=False)

            bounding_boxes = []
            for result in results:
                boxes = result.boxes
                for box in boxes:
                    x1, y1, x2, y2 = map(int, box.xyxy[0])
                    bounding_boxes.append((x1, y1, x2, y2))

            # Calculate angles for detected objects
            angles = calculate_object_angles(bounding_boxes, image_width=image.shape[1], image_height=image.shape[0], fov_deg=160)

            for result, angle_info in zip(results, angles):
                boxes = result.boxes
                for box in boxes:
                    x1, y1, x2, y2 = map(int, box.xyxy[0])
                    conf = float(box.conf[0])
                    cls_id = int(box.cls[0])
                    label = model.names[cls_id]

                    # Add horizontal angle to the label
                    horizontal_angle = angle_info["horizontal_angle_deg"]
                    label_with_angle = f'{label} {conf:.2f}'
                    angle_text = f'Angle: {horizontal_angle:.2f}°'
                    cv2.putText(image, angle_text, (x1, y1 - 25),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2)

                    # Draw bounding box and label
                    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.putText(image, label_with_angle, (x1, y1 - 10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2)

                    # Draw center point
                    center_x = (x1 + x2) // 2
                    center_y = (y1 + y2) // 2
                    cv2.circle(image, (center_x, center_y), 5, (0, 0, 255), -1)
                    cv2.putText(image, f"({center_x},{center_y})", (x1, y2 + 20),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

            # Display the processed image
            cv2.imshow("JetBot Camera with YOLO Detection", image)

        # Press 'q' to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cv2.destroyAllWindows()

# %%
def turn_x_degrees(jetbot_ip,degrees):
    V_MAX = 0.2  # Adjust this value as needed
    WHEEL_BASE = 0.1  # Distance between the wheels in meters
    if abs(degrees) > 0.5:
        degrees = 0.5*(degrees/abs(degrees))
    print("Degrees:", degrees)

    x = (degrees*0.1)/V_MAX
    print(x)
    if abs(degrees) > 0.05:
        if degrees > 0:
            left_speed = V_MAX
            right_speed = V_MAX * (1 - (degrees * 0.1) / WHEEL_BASE)
        else:
            left_speed = V_MAX * (1 + (degrees * 0.1) / WHEEL_BASE)
            right_speed = V_MAX
    else:
        left_speed = V_MAX
        right_speed = V_MAX

    print("Left Speed:", left_speed)
    print("Right Speed:", right_speed)
    # Set the motors
    set_motors(jetbot_ip, left_speed, right_speed)

# %%
def simple_pso_drive(jetbot_ip, fov_deg=160, window_name="JetBot Camera"):
    """
    A simplified PSO-like algorithm for robots to detect objects, calculate the average position,
    and drive towards the average angle, while displaying the camera stream with bounding boxes.
    """

    model = YOLO("models/yolov8n_trained.pt")  # Load the trained model

    url = f'http://{jetbot_ip}:8080/camera'


    while True:
        # Capture image from the robot's camera
        response = requests.get(url)
        img_array = np.frombuffer(response.content, dtype=np.uint8)
        image = cv2.imdecode(img_array, cv2.IMREAD_COLOR)

        if image is not None:
            # Detect objects using YOLO model
            results = model.predict(image, verbose=False)

            # Extract bounding box centers and draw bounding boxes
            centers = []
            to_close = False
            center_points = {}
            center_points[0] = []
            center_points[1] = []

            target_weight = 0.6



            for result in results:
                boxes = result.boxes
                for box in boxes:
                    x1, y1, x2, y2 = map(int, box.xyxy[0])
                    center_x = (x1 + x2) // 2
                    center_y = (y1 + y2) // 2
                    class_id = int(box.cls[0])                    

                    centers.append((center_x, center_y))
                    center_points[class_id].append(center_x)

                    # Draw bounding box and center point
                    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.circle(image, (center_x, center_y), 5, (0, 0, 255), -1)
                    cv2.putText(image, f"({center_x}, {center_y})", (x1, y1 - 10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2)
                    
                    print(f"X2-X1: {x2-x1}, Class ID: {class_id}")
                    if (x2-x1) > 55 and class_id == 0:
                        to_close = True
                    if (x2-x1) > 60 and class_id == 1:
                        to_close = True
                    

            if centers and not to_close:
                # Calculate the average center point
                # avg_center = np.mean(centers, axis=0)
                #reweight the centerpoints
                target_point, robot_point = 0, 0
                if len(center_points[0]) == 0:
                    target_weight = 1
                if len(center_points[1]) == 0:
                    target_weight = 0
                if len(center_points[1]) > 0:
                    target_point = (np.array(center_points[1])*target_weight)[0]
                print("CENTERPOINTS", center_points)
                if len(center_points[0]) > 0:
                    robot_point = np.mean((np.array(center_points[0])*(1-target_weight))/len(center_points[0]))
                avg_center = (target_point+ robot_point)
                print("AVG_CENTER", avg_center)

                # Calculate the horizontal angle to the average center
                image_width = image.shape[1]
                x_offset = (avg_center - image_width / 2) / (image_width / 2)
                horizontal_angle = x_offset * (fov_deg / 2)

                print(f"Average Center: {avg_center}, Horizontal Angle: {horizontal_angle:.2f}°")

                # Drive the robot towards the calculated angle
                turn_x_degrees(jetbot_ip, horizontal_angle/100)
            elif to_close:
                stop_robot(jetbot_ip)
            
            else:
                print("No objects detected. Stopping robot.")
                set_motors(jetbot_ip, -0.1, 0.1)

            # Display the processed image with bounding boxes
            cv2.imshow(window_name, image)

        # Press 'q' to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            stop_robot(jetbot_ip)
            break

    cv2.destroyAllWindows()

# %%
def calculate_object_angles(bounding_boxes, image_width, image_height, fov_deg):
    angles = []

    for box in bounding_boxes:
        x_min, y_min, x_max, y_max = box
        x_center = (x_min + x_max) / 2
        y_center = (y_min + y_max) / 2

        # Calculate horizontal angle
        x_offset = (x_center - image_width / 2) / (image_width / 2)
        horizontal_angle = x_offset * (fov_deg / 2)


        angles.append({
            "center": (x_center, y_center),
            "horizontal_angle_deg": horizontal_angle,
        })

    return angles

# %%
import multiprocessing

# Shared flag to stop all threads
stop_threads = multiprocessing.Event()

# Function to run simple_pso_drive for multiple robots in parallel
def run_multiple_robots(jetbot_ips, fov_deg=160):
    def robot_process(ip):
        # Create a unique window name for each robot
        window_name = f"JetBot Camera - {ip}"
        
        # Run the simple_pso_drive function with the unique window name
        simple_pso_drive(ip, fov_deg, window_name)

    processes = []

    for ip in jetbot_ips:
        process = multiprocessing.Process(target=robot_process, args=(ip,))
        processes.append(process)
        process.start()

    # Wait for all processes to complete
    for process in processes:
        process.join()

# Example usage
# jetbot_ip_list = ['194.47.156.140']
jetbot_ip_list = ['194.47.156.140', '194.47.156.221']
run_multiple_robots(jetbot_ip_list, fov_deg=160)
# Out:
# /home/v3/Documents/School/robotics/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:174: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# /home/v3/Documents/School/robotics/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:174: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# X2-X1: 12, Class ID: 1
# X2-X1: 10, Class ID: 0
# X2-X1: 11, Class ID: 0
# CENTERPOINTS {0: [138, 200], 1: [19]}
# AVG_CENTERX2-X1: 15, Class ID: 0
# 45.199999999999996X2-X1: 12, Class ID: 0
#
# Average Center: 45.199999999999996, Horizontal Angle: -47.71°
# CENTERPOINTSDegrees:  {0: [210, 56], 1: []}-0.4771428571428572
#
# -0.2385714285714286AVG_CENTER
#  Left Speed:66.5 0.10457142857142857
#
# Average Center: 66.5, Horizontal Angle: -32.50°Right Speed:
#  Degrees:0.2
# -0.325
# -0.1625
# Left Speed: 0.135
# Right Speed: 0.2
# Motors set successfullyMotors set successfully
#
# X2-X1: 15, Class ID: 1
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [146], 1: [24]}
# AVG_CENTER 72.80000000000001
# Average Center: 72.80000000000001, Horizontal Angle: -28.00°
# Degrees: -0.2799999999999999
# -0.13999999999999996
# Left Speed: 0.14400000000000002
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 9, Class ID: 0
# CENTERPOINTS {0: [218], 1: []}
# AVG_CENTER 218.0
# Average Center: 218.0, Horizontal Angle: 75.71°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 12, Class ID: 1
# X2-X1: 12, Class ID: 0
# CENTERPOINTS {0: [159], 1: [36]}
# AVG_CENTER 85.2
# Average Center: 85.2, Horizontal Angle: -19.14°
# Degrees: -0.19142857142857142
# -0.09571428571428571
# Motors set successfullyLeft Speed:
#  0.16171428571428573
# Right Speed: 0.2
# Motors set successfully
# No objects detected. Stopping robot.
# Motors set successfully
# X2-X1: 13, Class ID: 1
# X2-X1: 11, Class ID: 0
# CENTERPOINTS {0: [168], 1: [43]}
# AVG_CENTER 93.0
# Average Center: 93.0, Horizontal Angle: -13.57°
# Degrees: -0.13571428571428573
# -0.06785714285714287
# Left Speed: 0.17285714285714288
# Right Speed: 0.2
# No objects detected. Stopping robot.
# Motors set successfully
# Motors set successfully
# X2-X1: 14, Class ID: 1
# X2-X1: 10, Class ID: 0
# CENTERPOINTS No objects detected. Stopping robot.{0: [175], 1: [50]}
#
# AVG_CENTER 100.0
# Average Center: 100.0, Horizontal Angle: -8.57°
# Degrees: -0.08571428571428572
# Motors set successfully
# -0.04285714285714286
# Left Speed: 0.18285714285714286
# Right Speed: 0.2
# No objects detected. Stopping robot.
# Motors set successfully
# Motors set successfully
# X2-X1: 14, Class ID: 1
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [179], 1: [53]}
# AVG_CENTER 103.4
# Average Center: 103.4, Horizontal Angle: -6.14°
# Degrees: -0.06142857142857139
# -0.030714285714285694
# Left Speed: 0.18771428571428572
# Right Speed: 0.2
# X2-X1: 6, Class ID: 0
# CENTERPOINTS {0: [3], 1: []}
# AVG_CENTER 3.0
# Average Center: 3.0, Horizontal Angle: -77.86°
# Degrees: -0.5
# Motors set successfully-0.25
#
# Left Speed: 0.1
# Right Speed: 0.2
# X2-X1: 15, Class ID: 1
# X2-X1: 11, Class ID: 0
# CENTERPOINTS {0: [183], 1: [56]}
# AVG_CENTER 106.80000000000001
# Average Center: 106.80000000000001, Horizontal Angle: -3.71°
# Degrees: -0.03714285714285706
# -0.01857142857142853
# Left Speed: Motors set successfully0.2
#
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 12, Class ID: 0
# CENTERPOINTS {0: [7], 1: []}
# AVG_CENTER 7.0
# Average Center: 7.0, Horizontal Angle: -75.00°
# Degrees: -0.5
# -0.25
# Left Speed: 0.1
# Right Speed: 0.2
# X2-X1: 13, Class ID: 1
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [188], 1: [60]}
# AVG_CENTER 111.2
# Average Center: 111.2, Horizontal Angle: -0.57°
# Degrees:Motors set successfully
# -0.005714285714285694
# -0.0028571428571428467
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 12, Class ID: 0
# CENTERPOINTS {0: [11], 1: []}
# AVG_CENTER 11.0
# Average Center: 11.0, Horizontal Angle: -72.14°
# Degrees: -0.5
# -0.25
# Left Speed: 0.1
# Right Speed: 0.2
# X2-X1: 15, Class ID: 1
# X2-X1: 10, Class ID: 0
# Motors set successfullyCENTERPOINTS
# {0: [192], 1: [63]}
# AVG_CENTER 114.60000000000001
# Average Center: 114.60000000000001, Horizontal Angle: 1.86°
# Degrees: 0.018571428571428635
# 0.009285714285714317
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 14, Class ID: 0
# CENTERPOINTS {0: [17], 1: []}
# AVG_CENTER 17.0
# Average Center: 17.0, Horizontal Angle: -67.86°
# Degrees: -0.5
# -0.25
# Left Speed: 0.1
# Right Speed: 0.2
# X2-X1: 16, Class ID: 1
# X2-X1: 10, Class ID: 0
# X2-X1: 10, Class ID: 0
# CENTERPOINTS Motors set successfully{0: [193, 75], 1: [64]}
#
# AVG_CENTER 65.2
# Average Center: 65.2, Horizontal Angle: -33.43°
# Degrees: -0.33428571428571424
# -0.16714285714285712
# Left Speed: 0.13314285714285715
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 14, Class ID: 0
# CENTERPOINTS {0: [21], 1: []}
# AVG_CENTER 21.0
# Average Center: 21.0, Horizontal Angle: -65.00°
# Degrees: -0.5
# -0.25
# Left Speed: 0.1
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 15, Class ID: 1
# X2-X1: 10, Class ID: 0
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [195, 75], 1: [64]}
# AVG_CENTER 65.4
# Average Center: 65.4, Horizontal Angle: -33.29°
# Degrees: -0.33285714285714285
# -0.16642857142857143
# Left Speed: 0.13342857142857142
# Right Speed: 0.2
# X2-X1: 14, Class ID: 0
# CENTERPOINTS {0: [27], 1: []}
# AVG_CENTER 27.0
# Average Center: 27.0, Horizontal Angle: -60.71°
# Degrees: -0.5
# -0.25
# Left Speed: 0.1
# Right Speed: 0.2Motors set successfully
#
# Motors set successfully
# X2-X1: 17, Class ID: 1
# X2-X1: 5, Class ID: 0
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [2, 202], 1: [69]}
# AVG_CENTER 61.8
# Average Center: 61.8, Horizontal Angle: -35.86°
# Degrees: -0.3585714285714286
# -0.17928571428571427
# Left Speed: 0.1282857142857143
# Right Speed: 0.2
# X2-X1: 14, Class ID: 0
# CENTERPOINTS {0: [35], 1: []}
# AVG_CENTER 35.0
# Average Center: 35.0, Horizontal Angle: -55.00°
# Degrees: -0.5
# -0.25
# Left Speed: 0.1
# Motors set successfullyRight Speed:
#  0.2
# Motors set successfully
# X2-X1: 16, Class ID: 1
# X2-X1: 10, Class ID: 0
# X2-X1: 11, Class ID: 0
# CENTERPOINTS {0: [210, 5], 1: [78]}
# X2-X1: 15, Class ID: 0
# AVG_CENTERCENTERPOINTS  68.3{0: [42], 1: []}
#
# AVG_CENTERAverage Center: 68.3, Horizontal Angle: -31.21°
# 42.0Degrees:
#  Average Center: 42.0, Horizontal Angle: -50.00°
# -0.31214285714285717Degrees:
#  -0.15607142857142858-0.5
#
# Left Speed: -0.250.13757142857142857
#
# Right Speed:Left Speed: 0.2
# 0.1
# Right Speed: 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 15, Class ID: 0
# X2-X1: 15, Class ID: 0
# CENTERPOINTS {0: [50, 147], 1: []}
# AVG_CENTER 49.25
# Average Center: 49.25, Horizontal Angle: -44.82°
# Degrees: X2-X1: 16, Class ID: 1-0.4482142857142857
#
# -0.22410714285714284X2-X1: 7, Class ID: 0
#
# Left Speed:CENTERPOINTS  {0: [219], 1: [88]}0.11035714285714288
#
# Right Speed:AVG_CENTER  0.2
# 140.4
# Average Center: 140.4, Horizontal Angle: 20.29°
# Degrees: 0.20285714285714287
# 0.10142857142857144
# Left Speed: 0.2
# Right Speed:Motors set successfully
# 0.15942857142857145
# X2-X1: 16, Class ID: 0
# CENTERPOINTS {0: [55], 1: []}
# AVG_CENTER 55.0Motors set successfully
#
# Average Center: 55.0, Horizontal Angle: -40.71°
# Degrees: -0.4071428571428571
# -0.20357142857142854
# Left Speed: 0.1185714285714286
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 16, Class ID: 1
# CENTERPOINTS {0: [], 1: [98]}
# AVG_CENTER 98
# Average Center: 98, Horizontal Angle: -10.00°
# Degrees: -0.1
# -0.05000000000000001
# Left Speed: 0.18000000000000002
# Right Speed: 0.2
# X2-X1: 15, Class ID: 0
# X2-X1: 15, Class ID: 0
# CENTERPOINTS {0: [62, 162], 1: []}
# AVG_CENTER 56.0
# Average Center: 56.0, Horizontal Angle: -40.00°
# Degrees:Motors set successfully
#  -0.4
# -0.20000000000000004
# Left Speed: 0.11999999999999998
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 15, Class ID: 1
# CENTERPOINTS {0: [], 1: [101]}
# AVG_CENTER 101
# Average Center: 101, Horizontal Angle: -7.86°
# Degrees: -0.07857142857142857
# -0.039285714285714285
# Left Speed: 0.1842857142857143
# Right Speed: 0.2
# X2-X1: 15, Class ID: 0Motors set successfully
#
# CENTERPOINTS {0: [70], 1: []}
# AVG_CENTER 70.0
# Average Center: 70.0, Horizontal Angle: -30.00°
# Degrees: -0.3
# -0.15
# Left Speed: 0.13999999999999999
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 16, Class ID: 1
# X2-X1: 12, Class ID: 0
# CENTERPOINTS {0: [22], 1: [102]}
# AVG_CENTER 70.0
# Average Center: 70.0, Horizontal Angle: -30.00°
# Degrees: -0.3
# -0.15
# Left Speed: 0.13999999999999999
# Right Speed: 0.2
# X2-X1: 15, Class ID: 0
# CENTERPOINTS {0: [77], 1: []}
# AVG_CENTER 77.0
# Average Center: 77.0, Horizontal Angle: -25.00°
# Degrees: -0.25
# Motors set successfully-0.125
#
# Left Speed: 0.15000000000000002
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 15, Class ID: 1
# X2-X1: 13, Class ID: 0
# X2-X1: 11, Class ID: 0
# CENTERPOINTS {0: [22, 117], 1: [104]}
# AVG_CENTER 76.3
# Average Center: 76.3, Horizontal Angle: -25.50°
# Degrees: -0.25500000000000006
# -0.12750000000000003
# Left Speed: 0.149
# Right Speed: 0.2
# X2-X1: 15, Class ID: 0
# CENTERPOINTS {0: [84], 1: []}
# AVG_CENTER 84.0
# Average Center: 84.0, Horizontal Angle: -20.00°
# Degrees: -0.2
# -0.10000000000000002
# Left Speed: 0.16
# Right Speed: 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 17, Class ID: 1
# X2-X1: 14, Class ID: 0
# CENTERPOINTS {0: [26], 1: [110]}
# AVG_CENTER 76.4
# Average Center: 76.4, Horizontal Angle: -25.43°
# Degrees: X2-X1: 14, Class ID: 0-0.2542857142857142
#
# CENTERPOINTS-0.1271428571428571
# {0: [91], 1: []}Left Speed:
#  AVG_CENTER0.14914285714285716
# 91.0Right Speed:
#  Average Center: 91.0, Horizontal Angle: -15.00°0.2
#
# Degrees: -0.15
# -0.075
# Left Speed: 0.17
# Right Speed: 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 17, Class ID: 1
# CENTERPOINTS {0: [], 1: [122]}
# AVG_CENTER 122
# Average Center: 122, Horizontal Angle: 7.14°
# Degrees: 0.07142857142857144
# 0.03571428571428572
# Left Speed: 0.2
# Right Speed: X2-X1: 16, Class ID: 00.18571428571428572
#
# CENTERPOINTS {0: [95], 1: []}
# AVG_CENTER 95.0
# Average Center: 95.0, Horizontal Angle: -12.14°
# Degrees: -0.12142857142857143
# -0.060714285714285714
# Left Speed: 0.1757142857142857
# Right Speed: 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 17, Class ID: 1
# X2-X1: 11, Class ID: 0X2-X1: 14, Class ID: 0
#
# CENTERPOINTS CENTERPOINTS{0: [99], 1: []} {0: [44], 1: [130]}
#
# AVG_CENTER AVG_CENTER99.0
# 95.6Average Center: 99.0, Horizontal Angle: -9.29°
#
# Degrees:Average Center: 95.6, Horizontal Angle: -11.71°
# Degrees: -0.09285714285714286-0.11714285714285719
#
# -0.04642857142857143
# -0.058571428571428594Left Speed:
#  Left Speed:0.18142857142857144
# 0.17657142857142857Right Speed:
#  Right Speed:0.2
# 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 14, Class ID: 0
# CENTERPOINTS {0: [101], 1: []}
# AVG_CENTER 101.0
# Average Center: 101.0, Horizontal Angle: -7.86°
# Degrees: -0.07857142857142857
# -0.039285714285714285
# Left Speed: 0.1842857142857143
# Right Speed: 0.2
# X2-X1: 18, Class ID: 1
# CENTERPOINTS {0: [], 1: [136]}
# AVG_CENTER 136
# Average Center: 136, Horizontal Angle: 17.14°
# Degrees: 0.17142857142857143
# 0.08571428571428572
# Motors set successfullyLeft Speed:
#  0.2
# Right Speed: 0.1657142857142857
# Motors set successfully
# X2-X1: 15, Class ID: 0
# CENTERPOINTS {0: [102], 1: []}
# AVG_CENTER 102.0
# Average Center: 102.0, Horizontal Angle: -7.14°
# Degrees: -0.07142857142857144
# -0.03571428571428572
# Left Speed: 0.18571428571428572
# Right Speed: 0.2
# Motors set successfullyX2-X1: 17, Class ID: 1
#
# X2-X1: 11, Class ID: 0
# CENTERPOINTS {0: [48], 1: [139]}
# AVG_CENTER 102.6
# Average Center: 102.6, Horizontal Angle: -6.71°
# Degrees: -0.06714285714285718
# -0.03357142857142859
# Left Speed: 0.18657142857142858
# Right Speed: 0.2
# X2-X1: 15, Class ID: 0
# CENTERPOINTS {0: [104], 1: []}
# AVG_CENTER 104.0
# Average Center: 104.0, Horizontal Angle: -5.71°
# Degrees: -0.057142857142857134Motors set successfully
#
# -0.028571428571428567
# Left Speed: 0.18857142857142858
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 18, Class ID: 1
# X2-X1: 12, Class ID: 0
# CENTERPOINTS {0: [48], 1: [141]}
# AVG_CENTER 103.8
# Average Center: 103.8, Horizontal Angle: -5.86°
# Degrees: -0.058571428571428594
# -0.029285714285714297
# Left Speed: 0.18828571428571428
# Right Speed: 0.2
# X2-X1: 16, Class ID: 0
# X2-X1: 13, Class ID: 0
# CENTERPOINTS {0: [106, 216], 1: []}Motors set successfully
#
# AVG_CENTER 80.5
# Average Center: 80.5, Horizontal Angle: -22.50°
# Degrees: -0.225
# -0.1125
# Left Speed: 0.15500000000000003
# Right Speed: 0.2
# Motors set successfullyX2-X1: 19, Class ID: 1
#
# CENTERPOINTS {0: [], 1: [141]}
# AVG_CENTER 141
# Average Center: 141, Horizontal Angle: 20.71°
# Degrees: 0.20714285714285716
# 0.10357142857142858
# Left Speed: 0.2
# Right Speed: 0.15857142857142859
# X2-X1: 15, Class ID: 0
# CENTERPOINTS {0: [107], 1: []}
# AVG_CENTER 107.0
# Average Center: 107.0, Horizontal Angle: -3.57°
# Degrees: -0.03571428571428572
# Motors set successfully-0.01785714285714286
#
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 18, Class ID: 1
# CENTERPOINTS {0: [], 1: [145]}
# AVG_CENTER 145
# Average Center: 145, Horizontal Angle: 23.57°
# Degrees: 0.23571428571428574
# 0.11785714285714288
# Left Speed: 0.2
# Right Speed: 0.15285714285714286
# X2-X1: 16, Class ID: 0
# CENTERPOINTS {0: [110], 1: []}
# AVG_CENTER 110.0
# Average Center: 110.0, Horizontal Angle: -1.43°
# Degrees: -0.014285714285714284
# -0.007142857142857142
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 19, Class ID: 1
# CENTERPOINTS {0: [], 1: [144]}
# AVG_CENTER 144
# Average Center: 144, Horizontal Angle: 22.86°
# Degrees: 0.22857142857142854
# 0.11428571428571427X2-X1: 16, Class ID: 0
#
# Left Speed:CENTERPOINTS  0.2{0: [113], 1: []}
#
# Right Speed:AVG_CENTER  0.1542857142857143113.0
#
# Average Center: 113.0, Horizontal Angle: 0.71°
# Degrees: 0.007142857142857142
# 0.003571428571428571
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 16, Class ID: 0
# X2-X1: 19, Class ID: 1CENTERPOINTS
# CENTERPOINTS  {0: [113], 1: []}{0: [], 1: [141]}
#
# AVG_CENTERAVG_CENTER 141 113.0
#
# Average Center: 141, Horizontal Angle: 20.71°Average Center: 113.0, Horizontal Angle: 0.71°
#
# Degrees:Degrees:  0.207142857142857160.007142857142857142
#
# 0.103571428571428580.003571428571428571
#
# Left Speed:Left Speed: 0.2
# 0.2Right Speed:
#  Right Speed:0.15857142857142859
# 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 16, Class ID: 0
# CENTERPOINTS {0: [112], 1: []}
# AVG_CENTER 112.0
# Average Center: 112.0, Horizontal Angle: 0.00°
# Degrees: 0.0
# 0.0
# Left Speed: 0.2
# Right Speed: 0.2
# X2-X1: 19, Class ID: 1
# CENTERPOINTS {0: [], 1: [137]}
# Motors set successfullyAVG_CENTER
#  137
# Average Center: 137, Horizontal Angle: 17.86°
# Degrees: 0.17857142857142858
# 0.08928571428571429
# Left Speed: 0.2
# Right Speed: 0.16428571428571428
# Motors set successfully
# X2-X1: 17, Class ID: 0
# CENTERPOINTS {0: [112], 1: []}
# AVG_CENTER 112.0
# Average Center: 112.0, Horizontal Angle: 0.00°
# Degrees: 0.0
# 0.0
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 19, Class ID: 1
# CENTERPOINTS {0: [], 1: [135]}
# AVG_CENTER 135
# Average Center: 135, Horizontal Angle: 16.43°
# Degrees: 0.16428571428571426
# 0.08214285714285713
# Left Speed: 0.2
# Right Speed: 0.16714285714285715
# X2-X1: 17, Class ID: 0
# CENTERPOINTS {0: [113], 1: []}
# AVG_CENTER 113.0
# Average Center: 113.0, Horizontal Angle: 0.71°
# Degrees: 0.007142857142857142
# 0.003571428571428571Motors set successfully
#
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 21, Class ID: 1
# CENTERPOINTS {0: [], 1: [133]}
# AVG_CENTER 133
# Average Center: 133, Horizontal Angle: 15.00°
# Degrees: 0.15
# 0.075
# X2-X1: 18, Class ID: 0Left Speed:
#  CENTERPOINTS0.2
# {0: [114], 1: []}Right Speed:
#  AVG_CENTER0.17
# 114.0
# Average Center: 114.0, Horizontal Angle: 1.43°
# Degrees: 0.014285714285714284
# 0.007142857142857142
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 16, Class ID: 0
# CENTERPOINTS {0: [115], 1: []}
# AVG_CENTER 115.0
# Average Center: 115.0, Horizontal Angle: 2.14°
# Degrees: 0.02142857142857143
# 0.010714285714285714
# Left Speed:X2-X1: 20, Class ID: 1 0.2
# CENTERPOINTS
#  Right Speed: {0: [], 1: [130]}0.2
#
# AVG_CENTER 130
# Average Center: 130, Horizontal Angle: 12.86°
# Degrees: 0.1285714285714286
# 0.0642857142857143Motors set successfully
#
# Left Speed: 0.2
# Right Speed: 0.1742857142857143
# Motors set successfully
# X2-X1: 17, Class ID: 0
# CENTERPOINTS {0: [116], 1: []}
# AVG_CENTER 116.0
# Average Center: 116.0, Horizontal Angle: 2.86°
# Degrees: 0.028571428571428567
# 0.014285714285714284
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 21, Class ID: 1
# CENTERPOINTS {0: [], 1: [128]}
# AVG_CENTER 128
# Average Center: 128, Horizontal Angle: 11.43°
# Degrees: 0.11428571428571427
# 0.057142857142857134
# Left Speed: 0.2
# Right Speed: 0.17714285714285716
# X2-X1: 17, Class ID: 0
# CENTERPOINTS {0: [117], 1: []}
# AVG_CENTER 117.0
# Motors set successfullyAverage Center: 117.0, Horizontal Angle: 3.57°
#
# Degrees: 0.03571428571428572
# 0.01785714285714286
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 20, Class ID: 1
# CENTERPOINTS {0: [], 1: [129]}
# AVG_CENTER 129
# Average Center: 129, Horizontal Angle: 12.14°
# Degrees: 0.12142857142857143
# 0.060714285714285714
# Left Speed: 0.2
# Right Speed: 0.1757142857142857
# X2-X1: 18, Class ID: 0
# CENTERPOINTS {0: [118], 1: []}
# AVG_CENTER 118.0
# Average Center: 118.0, Horizontal Angle: 4.29°
# Motors set successfullyDegrees:
#  0.04285714285714286
# 0.02142857142857143
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 20, Class ID: 1
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [10], 1: [128]}
# AVG_CENTER 80.8
# Average Center: 80.8, Horizontal Angle: -22.29°
# Degrees: -0.22285714285714284
# -0.11142857142857142
# Left Speed: 0.15542857142857144
# Right Speed: 0.2
# X2-X1: 17, Class ID: 0
# CENTERPOINTS {0: [118], 1: []}
# AVG_CENTER 118.0
# Average Center: 118.0, Horizontal Angle: 4.29°
# Degrees: 0.04285714285714286
# 0.02142857142857143
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# Motors set successfully
# X2-X1: 20, Class ID: 1
# X2-X1: 12, Class ID: 0
# X2-X1: 15, Class ID: 0
# CENTERPOINTS {0: [20, 7], 1: [125]}
# AVG_CENTER 77.7
# Average Center: 77.7, Horizontal Angle: -24.50°
# Degrees: -0.24499999999999997
# -0.12249999999999998
# Left Speed: 0.15100000000000002X2-X1: 17, Class ID: 0
#
# Right Speed:CENTERPOINTS  0.2{0: [121], 1: []}
#
# AVG_CENTER 121.0
# Average Center: 121.0, Horizontal Angle: 6.43°
# Degrees: 0.0642857142857143
# 0.03214285714285715
# Left Speed: 0.2
# Right Speed: 0.18714285714285717Motors set successfully
#
# Motors set successfully
# X2-X1: 22, Class ID: 1
# X2-X1: 14, Class ID: 0
# CENTERPOINTS {0: [7], 1: [127]}
# AVG_CENTER 79.0
# Average Center: 79.0, Horizontal Angle: -23.57°
# Degrees: -0.23571428571428574
# -0.11785714285714288
# Left Speed: 0.15285714285714286
# Right Speed: 0.2
# X2-X1: 17, Class ID: 0
# CENTERPOINTS {0: [123], 1: []}
# AVG_CENTER 123.0
# Average Center: 123.0, Horizontal Angle: 7.86°
# Degrees:Motors set successfully
#  0.07857142857142857
# 0.039285714285714285
# Left Speed: 0.2
# Right Speed: 0.1842857142857143
# Motors set successfully
# X2-X1: 22, Class ID: 1
# X2-X1: 16, Class ID: 0
# CENTERPOINTS {0: [8], 1: [129]}
# AVG_CENTER 80.6
# Average Center: 80.6, Horizontal Angle: -22.43°
# Degrees: -0.22428571428571434
# -0.11214285714285718
# Left Speed: 0.15514285714285714
# Right Speed: 0.2
# X2-X1: 19, Class ID: 0
# CENTERPOINTS {0: [124], 1: []}
# AVG_CENTER 124.0
# Average Center: 124.0, Horizontal Angle: 8.57°
# Degrees: 0.08571428571428572
# 0.04285714285714286
# Left Speed: 0.2
# Right Speed: 0.18285714285714286
# Motors set successfully
# Motors set successfully
# X2-X1: 24, Class ID: 1
# X2-X1: 14, Class ID: 0
# CENTERPOINTS {0: [30], 1: [138]}
# AVG_CENTER 94.8
# Average Center: 94.8, Horizontal Angle: -12.29°
# Degrees: -0.12285714285714289
# -0.061428571428571443
# Left Speed: 0.17542857142857143
# Right Speed: 0.2
# X2-X1: 19, Class ID: 0
# CENTERPOINTS {0: [126], 1: []}
# AVG_CENTER 126.0
# Average Center: 126.0, Horizontal Angle: 10.00°
# Degrees:Motors set successfully
# 0.1
# 0.05000000000000001
# Left Speed: 0.2
# Right Speed: 0.18000000000000002
# Motors set successfully
# X2-X1: 23, Class ID: 1
# X2-X1: 12, Class ID: 0
# CENTERPOINTS {0: [33], 1: [144]}
# AVG_CENTER 99.6
# Average Center: 99.6, Horizontal Angle: -8.86°
# Degrees: -0.0885714285714286
# -0.044285714285714296
# Left Speed: 0.18228571428571427
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [127], 1: []}
# AVG_CENTER 127.0
# Average Center: 127.0, Horizontal Angle: 10.71°
# Degrees: 0.10714285714285714
# 0.05357142857142857
# Left Speed: 0.2
# Right Speed: 0.1785714285714286
# Motors set successfully
# X2-X1: 22, Class ID: 1
# CENTERPOINTS {0: [], 1: [152]}
# AVG_CENTER 152
# Average Center: 152, Horizontal Angle: 28.57°
# Degrees: 0.28571428571428575
# 0.14285714285714288
# Left Speed: 0.2
# Right Speed: 0.14285714285714285
# X2-X1: 19, Class ID: 0
# CENTERPOINTS {0: [127], 1: []}
# AVG_CENTER Motors set successfully127.0
#
# Average Center: 127.0, Horizontal Angle: 10.71°
# Degrees: 0.10714285714285714
# 0.05357142857142857
# Left Speed: 0.2
# Right Speed: 0.1785714285714286
# Motors set successfully
# X2-X1: 23, Class ID: 1
# X2-X1: 11, Class ID: 0
# CENTERPOINTS {0: [217], 1: [157]}
# AVG_CENTER 181.0
# Average Center: 181.0, Horizontal Angle: 49.29°
# Degrees: 0.49285714285714294
# 0.24642857142857147
# Left Speed: 0.2
# Right Speed: 0.10142857142857142
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [129], 1: []}
# AVG_CENTERMotors set successfully
#  129.0
# Average Center: 129.0, Horizontal Angle: 12.14°
# Degrees: 0.12142857142857143
# 0.060714285714285714
# Left Speed: 0.2
# Right Speed: 0.1757142857142857
# Motors set successfully
# X2-X1: 23, Class ID: 1
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [44], 1: [160]}
# AVG_CENTER 113.6
# Average Center: 113.6, Horizontal Angle: 1.14°
# Degrees: 0.011428571428571389
# 0.0057142857142856935
# Left Speed: 0.2
# Right Speed: 0.2
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [130], 1: []}
# AVG_CENTER 130.0
# Average Center: 130.0, Horizontal Angle: 12.86°
# Degrees: 0.1285714285714286
# 0.0642857142857143
# Left Speed: 0.2
# Right Speed:Motors set successfully 0.1742857142857143
#
# Motors set successfully
# X2-X1: 24, Class ID: 1
# CENTERPOINTS {0: [], 1: [156]}
# AVG_CENTER 156
# Average Center: 156, Horizontal Angle: 31.43°
# Degrees: 0.3142857142857143
# 0.15714285714285714
# Left Speed: 0.2
# Right Speed: 0.13714285714285715
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [130], 1: []}
# AVG_CENTER 130.0
# Average Center: 130.0, Horizontal Angle: 12.86°
# Degrees: 0.1285714285714286
# 0.0642857142857143
# Left Speed:Motors set successfully
# 0.2
# Right Speed: 0.1742857142857143
# Motors set successfully
# X2-X1: 24, Class ID: 1
# CENTERPOINTS {0: [], 1: [153]}
# AVG_CENTER 153
# Average Center: 153, Horizontal Angle: 29.29°
# Degrees: 0.29285714285714287
# 0.14642857142857144
# Left Speed: 0.2
# Right Speed: 0.14142857142857143
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [128], 1: []}
# AVG_CENTER 128.0
# Average Center: 128.0, Horizontal Angle: 11.43°
# Motors set successfullyDegrees:
#  0.11428571428571427
# 0.057142857142857134
# Left Speed: 0.2
# Right Speed: 0.17714285714285716
# Motors set successfully
# X2-X1: 24, Class ID: 1
# X2-X1: 14, Class ID: 0
# CENTERPOINTS {0: [7], 1: [152]}
# AVG_CENTER 94.0
# Average Center: 94.0, Horizontal Angle: -12.86°
# Degrees: -0.1285714285714286
# -0.0642857142857143
# Left Speed: 0.1742857142857143
# Right Speed: 0.2
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [131], 1: []}
# AVG_CENTERMotors set successfully
# 131.0
# Average Center: 131.0, Horizontal Angle: 13.57°
# Degrees: 0.13571428571428573
# 0.06785714285714287
# Left Speed: 0.2
# Right Speed: 0.17285714285714288
# Motors set successfully
# X2-X1: 26, Class ID: 1
# CENTERPOINTS {0: [], 1: [147]}
# AVG_CENTER 147
# Average Center: 147, Horizontal Angle: 25.00°
# Degrees: 0.25
# 0.125
# Left Speed: 0.2
# Right Speed: 0.15000000000000002
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [131], 1: []}
# AVG_CENTER 131.0Motors set successfully
#
# Average Center: 131.0, Horizontal Angle: 13.57°
# Degrees: 0.13571428571428573
# 0.06785714285714287
# Left Speed: 0.2
# Right Speed: 0.17285714285714288
# Motors set successfully
# X2-X1: 26, Class ID: 1
# CENTERPOINTS {0: [], 1: [148]}
# AVG_CENTER 148
# Average Center: 148, Horizontal Angle: 25.71°
# Degrees: 0.2571428571428572
# 0.1285714285714286
# Left Speed: 0.2
# Right Speed: 0.14857142857142858
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [132], 1: []}
# AVG_CENTER 132.0Motors set successfully
#
# Average Center: 132.0, Horizontal Angle: 14.29°
# Degrees: 0.14285714285714288
# 0.07142857142857144
# Left Speed: 0.2
# Right Speed: 0.17142857142857143
# Motors set successfully
# X2-X1: 26, Class ID: 1
# CENTERPOINTS {0: [], 1: [150]}
# AVG_CENTER 150
# Average Center: 150, Horizontal Angle: 27.14°
# Degrees: 0.27142857142857146
# 0.13571428571428573
# Left Speed: 0.2
# Right Speed: 0.1457142857142857
# Motors set successfully
# X2-X1: 22, Class ID: 0
# CENTERPOINTS {0: [132], 1: []}
# AVG_CENTER 132.0
# Average Center: 132.0, Horizontal Angle: 14.29°
# Degrees: 0.14285714285714288
# 0.07142857142857144
# Left Speed: 0.2
# Right Speed: 0.17142857142857143
# X2-X1: 26, Class ID: 1
# CENTERPOINTS {0: [], 1: [147]}
# AVG_CENTER 147
# Motors set successfullyAverage Center: 147, Horizontal Angle: 25.00°
#
# Degrees: 0.25
# 0.125
# Left Speed: 0.2
# Right Speed: 0.15000000000000002
# Motors set successfully
# X2-X1: 22, Class ID: 0
# CENTERPOINTS {0: [132], 1: []}
# AVG_CENTER 132.0
# Average Center: 132.0, Horizontal Angle: 14.29°
# Degrees: 0.14285714285714288
# 0.07142857142857144
# Left Speed: 0.2
# Right Speed: 0.17142857142857143
# Motors set successfully
# X2-X1: 27, Class ID: 1
# CENTERPOINTS {0: [], 1: [141]}
# AVG_CENTER 141
# Average Center: 141, Horizontal Angle: 20.71°
# Degrees: 0.20714285714285716
# 0.10357142857142858
# Left Speed: 0.2
# Right Speed: 0.15857142857142859
# X2-X1: 23, Class ID: 0
# CENTERPOINTS {0: [132], 1: []}
# AVG_CENTER 132.0
# Average Center: 132.0, Horizontal Angle: 14.29°Motors set successfully
#
# Degrees: 0.14285714285714288
# 0.07142857142857144
# Left Speed: 0.2
# Right Speed: 0.17142857142857143
# Motors set successfully
# X2-X1: 27, Class ID: 1
# X2-X1: 11, Class ID: 0
# CENTERPOINTS {0: [208], 1: [139]}
# AVG_CENTER 166.6
# Average Center: 166.6, Horizontal Angle: 39.00°
# Degrees: 0.3899999999999999
# 0.19499999999999995
# Left Speed: 0.2
# Right Speed: 0.12200000000000003
# X2-X1: 23, Class ID: 0
# CENTERPOINTS {0: [133], 1: []}
# AVG_CENTER 133.0
# Average Center: 133.0, Horizontal Angle: 15.00°
# Degrees: 0.15
# 0.075
# Left Speed: 0.2
# Right Speed: 0.17
# Motors set successfully
# Motors set successfully
# X2-X1: 24, Class ID: 0
# CENTERPOINTS {0: [134], 1: []}
# AVG_CENTER 134.0
# Average Center: 134.0, Horizontal Angle: 15.71°
# Degrees: 0.15714285714285714
# 0.07857142857142857
# Left Speed: 0.2
# X2-X1: 28, Class ID: 1Right Speed:
#  CENTERPOINTS0.1685714285714286
# {0: [], 1: [135]}
# AVG_CENTER 135
# Average Center: 135, Horizontal Angle: 16.43°
# Degrees: 0.16428571428571426
# 0.08214285714285713
# Left Speed: 0.2
# Right Speed: 0.16714285714285715
# Motors set successfully
# Motors set successfully
# X2-X1: 24, Class ID: 0
# CENTERPOINTS {0: [135], 1: []}
# AVG_CENTER 135.0
# Average Center: 135.0, Horizontal Angle: 16.43°
# Degrees: 0.16428571428571426
# 0.08214285714285713
# Left Speed: 0.2
# Right Speed: 0.16714285714285715
# X2-X1: 28, Class ID: 1
# CENTERPOINTS {0: [], 1: [131]}
# AVG_CENTER 131
# Average Center: 131, Horizontal Angle: 13.57°
# Degrees: 0.13571428571428573
# 0.06785714285714287Motors set successfully
#
# Left Speed: 0.2
# Right Speed: 0.17285714285714288
# Motors set successfully
# X2-X1: 30, Class ID: 1
# CENTERPOINTS {0: [], 1: [124]}
# AVG_CENTER 124
# Average Center: 124, Horizontal Angle: 8.57°
# Degrees: 0.08571428571428572
# 0.04285714285714286
# Left Speed: 0.2
# Right Speed: X2-X1: 24, Class ID: 00.18285714285714286
#
# CENTERPOINTS {0: [135], 1: []}
# AVG_CENTER 135.0
# Average Center: 135.0, Horizontal Angle: 16.43°
# Degrees: 0.16428571428571426
# 0.08214285714285713
# Left Speed: 0.2
# Right Speed: 0.16714285714285715
# Motors set successfully
# Motors set successfully
# X2-X1: 25, Class ID: 0
# CENTERPOINTS {0: [134], 1: []}
# AVG_CENTER 134.0
# Average Center: 134.0, Horizontal Angle: 15.71°
# Degrees: 0.15714285714285714
# 0.07857142857142857
# Left Speed: 0.2
# Right Speed: 0.1685714285714286
# X2-X1: 30, Class ID: 1
# CENTERPOINTS {0: [], 1: [122]}
# AVG_CENTER 122
# Average Center: 122, Horizontal Angle: 7.14°
# Motors set successfullyDegrees: 0.07142857142857144
#
# 0.03571428571428572
# Left Speed: 0.2
# Right Speed: 0.18571428571428572
# Motors set successfully
# X2-X1: 24, Class ID: 0
# CENTERPOINTS {0: [135], 1: []}
# AVG_CENTER 135.0
# Average Center: 135.0, Horizontal Angle: 16.43°
# Degrees: 0.16428571428571426
# 0.08214285714285713
# Left Speed: 0.2
# Right Speed: 0.16714285714285715
# X2-X1: 31, Class ID: 1
# X2-X1: 11, Class ID: 0
# CENTERPOINTS {0: [198], 1: [120]}
# AVG_CENTER 151.2
# Average Center: 151.2, Horizontal Angle: 28.00°
# Degrees: 0.2799999999999999
# 0.13999999999999996
# Left Speed: 0.2
# Right Speed: 0.14400000000000002
# Motors set successfully
# Motors set successfully
# X2-X1: 24, Class ID: 0
# CENTERPOINTS {0: [136], 1: []}
# AVG_CENTER 136.0
# X2-X1: 32, Class ID: 1Average Center: 136.0, Horizontal Angle: 17.14°
# Degrees: 0.17142857142857143
#
# 0.08571428571428572CENTERPOINTS
#  Left Speed:{0: [], 1: [122]}
# 0.2AVG_CENTER
#  Right Speed:122
# 0.1657142857142857Average Center: 122, Horizontal Angle: 7.14°
#
# Degrees: 0.07142857142857144
# 0.03571428571428572
# Left Speed: 0.2
# Right Speed: 0.18571428571428572
# Motors set successfully
# Motors set successfully
# X2-X1: 25, Class ID: 0
# CENTERPOINTS {0: [136], 1: []}
# AVG_CENTER 136.0
# Average Center: 136.0, Horizontal Angle: 17.14°
# Degrees: 0.17142857142857143
# 0.08571428571428572
# Left Speed: 0.2
# Right Speed: 0.1657142857142857
# X2-X1: 33, Class ID: 1
# CENTERPOINTS {0: [], 1: [119]}Motors set successfully
#
# AVG_CENTER 119
# Average Center: 119, Horizontal Angle: 5.00°
# Degrees: 0.05
# 0.025000000000000005
# Left Speed: 0.2
# Right Speed: 0.2
# X2-X1: 24, Class ID: 0
# X2-X1: 7, Class ID: 0
# CENTERPOINTS {0: [137, 220], 1: []}Motors set successfully
#
# AVG_CENTER 89.25
# Average Center: 89.25, Horizontal Angle: -16.25°
# Degrees: -0.1625
# -0.08125
# Left Speed: 0.1675
# Right Speed: 0.2
# X2-X1: 32, Class ID: 1
# CENTERPOINTSMotors set successfully
# {0: [], 1: [117]}
# AVG_CENTER 117
# Average Center: 117, Horizontal Angle: 3.57°
# Degrees: 0.03571428571428572
# 0.01785714285714286
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 26, Class ID: 0
# CENTERPOINTS {0: [138], 1: []}
# AVG_CENTER 138.0
# Average Center: 138.0, Horizontal Angle: 18.57°
# Degrees: 0.18571428571428572
# 0.09285714285714286
# Left Speed: 0.2
# Right Speed: 0.16285714285714287
# X2-X1: 33, Class ID: 1
# CENTERPOINTS {0: [], 1: [117]}
# AVG_CENTER 117
# Average Center: 117, Horizontal Angle: 3.57°
# Motors set successfullyDegrees:
#  0.03571428571428572
# 0.01785714285714286
# Left Speed: 0.2
# Right Speed: 0.2
# Motors set successfully
# X2-X1: 23, Class ID: 0
# CENTERPOINTS {0: [143], 1: []}
# AVG_CENTER 143.0
# Average Center: 143.0, Horizontal Angle: 22.14°
# Degrees: 0.22142857142857145
# 0.11071428571428572
# Left Speed: 0.2
# Right Speed: 0.15571428571428572
# X2-X1: 36, Class ID: 1
# CENTERPOINTS {0: [], 1: [120]}
# AVG_CENTER 120
# Average Center: 120, Horizontal Angle: 5.71°
# Degrees: 0.057142857142857134
# 0.028571428571428567
# Motors set successfullyLeft Speed:
#  0.2
# Right Speed: 0.18857142857142858
# Motors set successfully
# X2-X1: 23, Class ID: 0
# CENTERPOINTS {0: [146], 1: []}
# AVG_CENTER 146.0
# Average Center: 146.0, Horizontal Angle: 24.29°
# Degrees: 0.24285714285714285
# 0.12142857142857143
# Left Speed: 0.2
# Right Speed: 0.15142857142857144
# X2-X1: 36, Class ID: 1
# CENTERPOINTS {0: [], 1: [122]}
# AVG_CENTERMotors set successfully 122
#
# Average Center: 122, Horizontal Angle: 7.14°
# Degrees: 0.07142857142857144
# 0.03571428571428572
# Left Speed: 0.2
# Right Speed: 0.18571428571428572
# Motors set successfully
# X2-X1: 22, Class ID: 0
# CENTERPOINTS {0: [148], 1: []}
# AVG_CENTER 148.0
# Average Center: 148.0, Horizontal Angle: 25.71°
# Degrees: 0.2571428571428572
# 0.1285714285714286
# Left Speed: 0.2
# Right Speed: 0.14857142857142858
# X2-X1: 38, Class ID: 1
# CENTERPOINTS {0: [], 1: [124]}
# AVG_CENTER 124
# Motors set successfullyAverage Center: 124, Horizontal Angle: 8.57°
#
# Degrees: 0.08571428571428572
# 0.04285714285714286
# Left Speed: 0.2
# Right Speed: 0.18285714285714286
# X2-X1: 22, Class ID: 0
# Motors set successfullyCENTERPOINTS
#  {0: [147], 1: []}
# AVG_CENTER 147.0
# Average Center: 147.0, Horizontal Angle: 25.00°
# Degrees: 0.25
# 0.125
# Left Speed: 0.2
# Right Speed: 0.15000000000000002
# X2-X1: 40, Class ID: 1
# CENTERPOINTSMotors set successfully
# {0: [], 1: [125]}
# AVG_CENTER 125
# Average Center: 125, Horizontal Angle: 9.29°
# Degrees: 0.09285714285714286
# 0.04642857142857143
# Left Speed: 0.2
# Right Speed: 0.18142857142857144
# X2-X1: 26, Class ID: 0
# CENTERPOINTSMotors set successfully
# {0: [147], 1: []}
# AVG_CENTER 147.0
# Average Center: 147.0, Horizontal Angle: 25.00°
# Degrees: 0.25
# 0.125
# Left Speed: 0.2
# Right Speed: 0.15000000000000002
# Motors set successfully
# X2-X1: 40, Class ID: 1
# CENTERPOINTS {0: [], 1: [126]}
# AVG_CENTER 126
# Average Center: 126, Horizontal Angle: 10.00°
# Degrees: 0.1
# 0.05000000000000001
# Left Speed: 0.2
# Right Speed: 0.18000000000000002
# X2-X1: 24, Class ID: 0
# CENTERPOINTS {0: [145], 1: []}
# AVG_CENTER 145.0
# Average Center: 145.0, Horizontal Angle: 23.57°
# Degrees: 0.23571428571428574
# 0.11785714285714288
# Motors set successfullyLeft Speed:
# 0.2
# Right Speed: 0.15285714285714286
# Motors set successfully
# X2-X1: 42, Class ID: 1
# CENTERPOINTS {0: [], 1: [128]}
# AVG_CENTER 128
# Average Center: 128, Horizontal Angle: 11.43°
# Degrees: 0.11428571428571427
# 0.057142857142857134
# Left Speed: 0.2
# Right Speed: 0.17714285714285716
# X2-X1: 25, Class ID: 0
# CENTERPOINTS {0: [144], 1: []}
# AVG_CENTER 144.0
# Motors set successfullyAverage Center: 144.0, Horizontal Angle: 22.86°
#
# Degrees: 0.22857142857142854
# 0.11428571428571427
# Left Speed: 0.2
# Right Speed: 0.1542857142857143
# X2-X1: 46, Class ID: 1
# CENTERPOINTS {0: [], 1: [127]}
# AVG_CENTER 127
# Average Center: 127, Horizontal Angle: 10.71°
# Degrees: 0.10714285714285714
# 0.05357142857142857
# Left Speed: 0.2
# Right Speed: 0.1785714285714286
# Motors set successfully
# Motors set successfully
# X2-X1: 48, Class ID: 1
# CENTERPOINTS {0: [], 1: [127]}
# AVG_CENTER 127
# Average Center: 127, Horizontal Angle: 10.71°
# Degrees: 0.10714285714285714
# 0.05357142857142857
# Left Speed: 0.2
# Right Speed: 0.1785714285714286
# X2-X1: 25, Class ID: 0
# X2-X1: 12, Class ID: 0
# CENTERPOINTS {0: [143, 9], 1: []}
# AVG_CENTERMotors set successfully
# 38.0
# Average Center: 38.0, Horizontal Angle: -52.86°
# Degrees: -0.5
# -0.25
# Left Speed: 0.1
# Right Speed: 0.2
# X2-X1: 50, Class ID: 1
# CENTERPOINTS {0: [], 1: [128]}
# AVG_CENTER 128
# Average Center: 128, Horizontal Angle: 11.43°
# Degrees: 0.11428571428571427
# 0.057142857142857134
# Left Speed: 0.2
# Right Speed: 0.17714285714285716
# Motors set successfully
# Motors set successfully
# X2-X1: 26, Class ID: 0
# CENTERPOINTS {0: [143], 1: []}
# AVG_CENTER 143.0
# Average Center: 143.0, Horizontal Angle: 22.14°
# Degrees: 0.22142857142857145
# 0.11071428571428572
# Left Speed: 0.2
# Right Speed: 0.15571428571428572
# X2-X1: 51, Class ID: 1
# CENTERPOINTS {0: [], 1: [128]}
# AVG_CENTER 128
# Average Center: 128, Horizontal Angle: 11.43°
# Degrees: 0.11428571428571427
# 0.057142857142857134
# Left Speed:Motors set successfully
# 0.2
# Right Speed: 0.17714285714285716
# Motors set successfully
# X2-X1: 25, Class ID: 0
# CENTERPOINTS {0: [150], 1: []}
# AVG_CENTER 150.0
# Average Center: 150.0, Horizontal Angle: 27.14°
# Degrees: 0.27142857142857146
# 0.13571428571428573
# Left Speed: 0.2
# Right Speed: 0.1457142857142857
# X2-X1: 52, Class ID: 1
# CENTERPOINTS {0: [], 1: [129]}
# AVG_CENTER 129
# Average Center: 129, Horizontal Angle: 12.14°
# Degrees: Motors set successfully0.12142857142857143
#
# 0.060714285714285714
# Left Speed: 0.2
# Right Speed: 0.1757142857142857
# Motors set successfully
# X2-X1: 27, Class ID: 0
# CENTERPOINTS {0: [156], 1: []}
# AVG_CENTER 156.0
# Average Center: 156.0, Horizontal Angle: 31.43°
# Degrees: 0.3142857142857143
# 0.15714285714285714
# Left Speed: 0.2
# Right Speed: 0.13714285714285715
# X2-X1: 52, Class ID: 1
# CENTERPOINTS {0: [], 1: [129]}
# AVG_CENTER 129
# Average Center: 129, Horizontal Angle: 12.14°
# Degrees: 0.12142857142857143
# Motors set successfully0.060714285714285714
#
# Left Speed: 0.2
# Right Speed: 0.1757142857142857
# Motors set successfully
# X2-X1: 26, Class ID: 0
# CENTERPOINTS {0: [156], 1: []}
# AVG_CENTER 156.0
# Average Center: 156.0, Horizontal Angle: 31.43°
# Degrees: 0.3142857142857143
# 0.15714285714285714
# Left Speed: 0.2
# Right Speed: 0.13714285714285715
# X2-X1: 53, Class ID: 1
# CENTERPOINTS {0: [], 1: [129]}
# AVG_CENTER Motors set successfully129
#
# Average Center: 129, Horizontal Angle: 12.14°
# Degrees: 0.12142857142857143
# 0.060714285714285714
# Left Speed: 0.2
# Right Speed: 0.1757142857142857
# Motors set successfully
# X2-X1: 27, Class ID: 0
# CENTERPOINTS {0: [154], 1: []}
# AVG_CENTER 154.0
# Average Center: 154.0, Horizontal Angle: 30.00°
# Degrees: 0.3
# 0.15
# Left Speed: 0.2
# Right Speed: 0.13999999999999999
# X2-X1: 55, Class ID: 1
# CENTERPOINTS {0: [], 1: [130]}
# AVG_CENTER 130
# Average Center: 130, Horizontal Angle: 12.86°
# Degrees: 0.1285714285714286
# 0.0642857142857143
# Left Speed: 0.2
# Right Speed: 0.1742857142857143
# Motors set successfully
# Motors set successfully
# X2-X1: 25, Class ID: 0
# CENTERPOINTS {0: [151], 1: []}
# AVG_CENTER 151.0
# Average Center: 151.0, Horizontal Angle: 27.86°
# Degrees: 0.2785714285714285
# 0.13928571428571426
# Left Speed: 0.2
# Right Speed: 0.14428571428571432
# X2-X1: 60, Class ID: 1
# CENTERPOINTS {0: [], 1: [130]}
# AVG_CENTER 130
# Average Center: 130, Horizontal Angle: 12.86°
# Degrees: 0.1285714285714286
# 0.0642857142857143
# Left Speed: 0.2
# Motors set successfully
# Right Speed: 0.1742857142857143
# Motors set successfully
# X2-X1: 25, Class ID: 0
# CENTERPOINTS {0: [151], 1: []}
# AVG_CENTER 151.0
# Average Center: 151.0, Horizontal Angle: 27.86°
# Degrees: 0.2785714285714285
# 0.13928571428571426
# Left Speed: 0.2X2-X1: 65, Class ID: 1
#
# Right Speed: 0.14428571428571432
# Motors set successfully
# Stop command executed successfully
# X2-X1: 24, Class ID: 0
# CENTERPOINTS {0: [149], 1: []}
# AVG_CENTER 149.0
# Average Center: 149.0, Horizontal Angle: 26.43°
# Degrees: 0.2642857142857143
# 0.13214285714285715
# Left Speed: 0.2
# Right Speed: 0.14714285714285716X2-X1: 67, Class ID: 1
#
# Stop command executed successfully
# Motors set successfully
# X2-X1: 71, Class ID: 1
# X2-X1: 25, Class ID: 0
# CENTERPOINTS {0: [146], 1: []}Stop command executed successfully
#
# AVG_CENTER 146.0
# Average Center: 146.0, Horizontal Angle: 24.29°
# Degrees: 0.24285714285714285
# 0.12142857142857143
# Left Speed: 0.2
# Right Speed: 0.15142857142857144
# X2-X1: 67, Class ID: 1Motors set successfully
#
# Stop command executed successfully
# X2-X1: 25, Class ID: 0
# X2-X1: 11, Class ID: 1
# CENTERPOINTS {0: [143], 1: [192]}
# AVG_CENTER 172.39999999999998
# Average Center: 172.39999999999998, Horizontal Angle: 43.14°
# Degrees: 0.4314285714285713
# 0.21571428571428564
# Left Speed: 0.2
# Right Speed: 0.11371428571428575
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 25, Class ID: 0
# X2-X1: 10, Class ID: 1
# CENTERPOINTS {0: [141], 1: [189]}
# AVG_CENTER 169.8
# Average Center: 169.8, Horizontal Angle: 41.29°
# Degrees: 0.4128571428571429
# 0.20642857142857146
# Left Speed: 0.2
# Right Speed: 0.11742857142857142
# X2-X1: 67, Class ID: 1
# Motors set successfully
# Stop command executed successfully
# X2-X1: 25, Class ID: 0
# CENTERPOINTS {0: [137], 1: []}
# AVG_CENTER 137.0
# Average Center: 137.0, Horizontal Angle: 17.86°
# Degrees: 0.17857142857142858
# 0.08928571428571429
# Left Speed: 0.2
# Right Speed: 0.16428571428571428
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 25, Class ID: 0
# X2-X1: 11, Class ID: 0
# X2-X1: 12, Class ID: 1
# CENTERPOINTS {0: [131, 168], 1: [176]}
# AVG_CENTER 135.5
# Average Center: 135.5, Horizontal Angle: 16.79°
# Degrees: 0.16785714285714284
# 0.08392857142857142
# Left Speed: 0.2
# Right Speed: 0.16642857142857145
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 25, Class ID: 0
# X2-X1: 10, Class ID: 0
# X2-X1: 10, Class ID: 1
# CENTERPOINTS {0: [129, 165], 1: [172]}
# AVG_CENTER 132.6
# Average Center: 132.6, Horizontal Angle: 14.71°X2-X1: 67, Class ID: 1
#
# Degrees: 0.14714285714285713
# 0.07357142857142857
# Left Speed: 0.2
# Right Speed: 0.1705714285714286
# Stop command executed successfully
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 24, Class ID: 0
# X2-X1: 10, Class ID: 0
# X2-X1: 13, Class ID: 1
# CENTERPOINTS {0: [129, 162], 1: [169]}
# AVG_CENTER 130.5
# Average Center: 130.5, Horizontal Angle: 13.21°
# Degrees: 0.13214285714285715
# 0.06607142857142857
# Left Speed: 0.2
# Right Speed: 0.1735714285714286
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 23, Class ID: 0
# X2-X1: 10, Class ID: 0
# X2-X1: 11, Class ID: 1
# CENTERPOINTS {0: [126, 156], 1: [164]}
# AVG_CENTER 126.6
# Average Center: 126.6, Horizontal Angle: 10.43°
# Degrees: 0.10428571428571426
# 0.05214285714285713
# Left Speed: 0.2
# Right Speed: 0.17914285714285716
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 22, Class ID: 0
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [126, 154], 1: []}X2-X1: 67, Class ID: 1
#
# AVG_CENTER 70.0
# Average Center: 70.0, Horizontal Angle: -30.00°
# Degrees: -0.3
# -0.15
# Left Speed: 0.13999999999999999
# Right Speed: Stop command executed successfully0.2
#
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 22, Class ID: 0
# X2-X1: 9, Class ID: 0
# X2-X1: 10, Class ID: 1
# CENTERPOINTS {0: [125, 152], 1: [162]}
# AVG_CENTER 124.9
# Average Center: 124.9, Horizontal Angle: 9.21°
# Degrees: 0.09214285714285719
# 0.046071428571428596
# Left Speed: 0.2
# Right Speed: 0.18157142857142858
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 67, Class ID: 1X2-X1: 22, Class ID: 0
#
# X2-X1: 10, Class ID: 0
# X2-X1: 11, Class ID: 1
# CENTERPOINTS {0: [129, 155], 1: [164]}
# AVG_CENTER 126.79999999999998
# Average Center: 126.79999999999998, Horizontal Angle: 10.57°
# Degrees: 0.1057142857142856
# Stop command executed successfully0.0528571428571428
#
# Left Speed: 0.2
# Right Speed: 0.17885714285714288
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# X2-X1: 9, Class ID: 0
# X2-X1: 13, Class ID: 1
# CENTERPOINTS {0: [131, 157], 1: [165]}
# AVG_CENTER 127.80000000000001
# Average Center: 127.80000000000001, Horizontal Angle: 11.29°
# Degrees: 0.11285714285714295
# 0.056428571428571474
# Left Speed: 0.2
# Right Speed: 0.1774285714285714
# X2-X1: 67, Class ID: 1
# Motors set successfully
# Stop command executed successfully
# X2-X1: 22, Class ID: 0
# X2-X1: 12, Class ID: 1
# X2-X1: 9, Class ID: 0
# CENTERPOINTS X2-X1: 68, Class ID: 1{0: [132, 157], 1: [166]}
#
# AVG_CENTER 128.5
# Average Center: 128.5, Horizontal Angle: 11.79°
# Degrees: 0.11785714285714287
# Stop command executed successfully0.05892857142857144
#
# Left Speed: 0.2
# Right Speed: 0.17642857142857143
# Motors set successfully
# X2-X1: 68, Class ID: 1
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# X2-X1: 9, Class ID: 0
# X2-X1: 11, Class ID: 1
# CENTERPOINTS {0: [131, 156], 1: [164]}
# AVG_CENTER 127.1
# Average Center: 127.1, Horizontal Angle: 10.79°
# Degrees: 0.10785714285714282
# 0.05392857142857141
# X2-X1: 67, Class ID: 1Left Speed:
#  0.2
# Right Speed: 0.17842857142857144
# Stop command executed successfully
# Motors set successfully
# X2-X1: 68, Class ID: 1X2-X1: 21, Class ID: 0
# X2-X1: 9, Class ID: 0
# X2-X1: 10, Class ID: 1
#
# CENTERPOINTS {0: [129, 153], 1: [162]}
# AVG_CENTER 125.4
# Average Center: 125.4, Horizontal Angle: 9.57°
# Degrees:Stop command executed successfully
# 0.09571428571428575
# 0.047857142857142876
# Left Speed: 0.2
# Right Speed: 0.18085714285714286
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 22, Class ID: 0
# X2-X1: 10, Class ID: 0
# X2-X1: 10, Class ID: 1
# CENTERPOINTS {0: [129, 151], 1: [161]}
# AVG_CENTER 124.6
# Average Center: 124.6, Horizontal Angle: 9.00°
# Degrees: 0.08999999999999997
# 0.044999999999999984
# Left Speed: 0.2
# Right Speed: 0.18200000000000002
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 22, Class ID: 0
# X2-X1: 9, Class ID: 0
# X2-X1: 11, Class ID: 1
# CENTERPOINTS {0: [128, 150], 1: [160]}
# AVG_CENTER 123.8
# Average Center: 123.8, Horizontal Angle: 8.43°
# Degrees: 0.08428571428571427
# 0.042142857142857135
# Left Speed: 0.2
# Right Speed: 0.18314285714285716
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 22, Class ID: 0X2-X1: 67, Class ID: 1
#
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [128, 150], 1: []}
# AVG_CENTER 69.5
# Average Center: 69.5, Horizontal Angle: -30.36°
# Degrees:Stop command executed successfully
# -0.30357142857142855
# -0.15178571428571427
# Left Speed: 0.1392857142857143
# Right Speed: 0.2
# Motors set successfullyX2-X1: 68, Class ID: 1
#
# Stop command executed successfully
# X2-X1: 22, Class ID: 0
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [128, 150], 1: []}
# AVG_CENTER 69.5
# Average Center: 69.5, Horizontal Angle: -30.36°
# Degrees: -0.30357142857142855
# -0.15178571428571427
# Left Speed: 0.1392857142857143
# Right Speed: 0.2
# Motors set successfullyX2-X1: 67, Class ID: 1
#
# Stop command executed successfully
# X2-X1: 22, Class ID: 0
# X2-X1: 10, Class ID: 0
# X2-X1: 10, Class ID: 1
# CENTERPOINTS {0: [130, 151], 1: [161]}
# AVG_CENTER 124.69999999999999
# Average Center: 124.69999999999999, Horizontal Angle: 9.07°
# Degrees: 0.09071428571428564
# 0.04535714285714282
# Left Speed: 0.2
# Right Speed: 0.18185714285714288X2-X1: 67, Class ID: 1
#
# Stop command executed successfully
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 22, Class ID: 0
# X2-X1: 12, Class ID: 1
# X2-X1: 10, Class ID: 0
# CENTERPOINTS {0: [137, 158], 1: [167]}
# AVG_CENTER 129.7
# Average Center: 129.7, Horizontal Angle: 12.64°
# Degrees: 0.12642857142857136
# 0.06321428571428568
# Left Speed: 0.2
# Right Speed: 0.17471428571428574
# X2-X1: 68, Class ID: 1
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# X2-X1: 11, Class ID: 1
# X2-X1: 9, Class ID: 0
# CENTERPOINTS {0: [144, 164], 1: [172]}
# AVG_CENTER 134.0
# Average Center: 134.0, Horizontal Angle: 15.71°
# Degrees: 0.15714285714285714
# 0.07857142857142857X2-X1: 67, Class ID: 1
#
# Left Speed:0.2
# Right Speed: 0.1685714285714286
# Stop command executed successfully
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 20, Class ID: 0
# X2-X1: 11, Class ID: 1
# CENTERPOINTS {0: [145], 1: [172]}
# AVG_CENTER 161.2
# Average Center: 161.2, Horizontal Angle: 35.14°
# Degrees: 0.3514285714285713
# 0.17571428571428566
# Left Speed: 0.2
# Right Speed: 0.12971428571428575
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfullyX2-X1: 21, Class ID: 0
#
# X2-X1: 11, Class ID: 1
# CENTERPOINTS {0: [144], 1: [170]}
# AVG_CENTER 159.6
# Average Center: 159.6, Horizontal Angle: 34.00°
# Degrees: 0.3399999999999999
# 0.16999999999999996
# Left Speed: 0.2
# Right Speed: 0.13200000000000003
# X2-X1: 67, Class ID: 1
# Motors set successfully
# Stop command executed successfully
# X2-X1: 20, Class ID: 0
# X2-X1: 12, Class ID: 1
# CENTERPOINTS {0: [141], 1: [165]}
# AVG_CENTER 155.4
# Average Center: 155.4, Horizontal Angle: 31.00°
# Degrees: 0.31000000000000005
# 0.15500000000000003
# Left Speed: 0.2
# Right Speed: 0.13799999999999998
# Motors set successfully
# X2-X1: 67, Class ID: 1
# Stop command executed successfully
# X2-X1: 23, Class ID: 0
# X2-X1: 11, Class ID: 1
# X2-X1: 22, Class ID: 0
# CENTERPOINTS {0: [135, 139], 1: [160]}
# AVG_CENTER 123.4
# Average Center: 123.4, Horizontal Angle: 8.14°
# Degrees: 0.08142857142857148
# 0.04071428571428574
# X2-X1: 66, Class ID: 1Left Speed:
#  0.2
# Right Speed: 0.18371428571428572
# Stop command executed successfully
# Motors set successfully
# X2-X1: 64, Class ID: 1
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# X2-X1: 12, Class ID: 1
# X2-X1: 9, Class ID: 0
# CENTERPOINTS {0: [131, 147], 1: [155]}
# AVG_CENTER 120.80000000000001
# ...
# X2-X1: 64, Class ID: 0
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Stop command executed successfullyDegrees:
#  0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 63, Class ID: 0
# Stop command executed successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 61, Class ID: 0
# X2-X1: 11, Class ID: 0
# Stop command executed successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 62, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 63, Class ID: 0Motors set successfully
#
# Stop command executed successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# X2-X1: 63, Class ID: 0Right Speed:
#  0.1X2-X1: 10, Class ID: 0
#
# Motors set successfullyStop command executed successfully
#
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed:X2-X1: 63, Class ID: 0
# 0.2
# Right Speed: 0.1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 63, Class ID: 0
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}Stop command executed successfully
#
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 11, Class ID: 0
# Stop command executed successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 61, Class ID: 0
# X2-X1: 19, Class ID: 0
# Stop command executed successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 62, Class ID: 0
# X2-X1: 11, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 61, Class ID: 0
# X2-X1: 10, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# X2-X1: 61, Class ID: 0Left Speed:
# X2-X1: 11, Class ID: 00.2
#
# Right Speed: 0.1
# Motors set successfullyStop command executed successfully
#
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTERX2-X1: 62, Class ID: 0
# 212.0X2-X1: 11, Class ID: 0
#
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Stop command executed successfullyRight Speed:
#  0.1
# Motors set successfully
# X2-X1: 63, Class ID: 0
# X2-X1: 11, Class ID: 0
# X2-X1: 21, Class ID: 0
# Stop command executed successfullyX2-X1: 21, Class ID: 0
#
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 61, Class ID: 0
# X2-X1: 10, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 61, Class ID: 0
# X2-X1: 10, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees:X2-X1: 62, Class ID: 0
# 0.5X2-X1: 18, Class ID: 0
# X2-X1: 11, Class ID: 0
#
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1Stop command executed successfully
#
# Motors set successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 10, Class ID: 0
# X2-X1: 21, Class ID: 0X2-X1: 19, Class ID: 0
#
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees:Stop command executed successfully
# 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 63, Class ID: 0
# X2-X1: 10, Class ID: 0
# Stop command executed successfullyX2-X1: 21, Class ID: 0
#
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 11, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 63, Class ID: 0
# X2-X1: 11, Class ID: 0
# Stop command executed successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 62, Class ID: 0
# X2-X1: 10, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# X2-X1: 61, Class ID: 0Right Speed:
#  X2-X1: 11, Class ID: 00.1
#
# Stop command executed successfullyMotors set successfully
#
# X2-X1: 20, Class ID: 0
# CENTERPOINTS X2-X1: 63, Class ID: 0{0: [213], 1: []}
# X2-X1: 10, Class ID: 0
#
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Stop command executed successfullyLeft Speed:
#  0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 61, Class ID: 0
# X2-X1: 11, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 62, Class ID: 0
# X2-X1: 11, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 61, Class ID: 0
# X2-X1: 10, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 63, Class ID: 0
# X2-X1: 12, Class ID: 0
# X2-X1: 20, Class ID: 0
# Stop command executed successfully
# Motors set successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 11, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1X2-X1: 61, Class ID: 0
#
# X2-X1: 10, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 61, Class ID: 0
# X2-X1: 10, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
#  Degrees:0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 63, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°X2-X1: 62, Class ID: 0
#
# Degrees:X2-X1: 11, Class ID: 0
# 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 10, Class ID: 0
# X2-X1: 21, Class ID: 0
# CENTERPOINTS Stop command executed successfully{0: [212], 1: []}
#
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 61, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 63, Class ID: 0Motors set successfully
#
# X2-X1: 11, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# X2-X1: 63, Class ID: 0Average Center: 212.0, Horizontal Angle: 71.43°
#
# X2-X1: 11, Class ID: 0Degrees:
#  0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 63, Class ID: 0
# X2-X1: 10, Class ID: 0X2-X1: 21, Class ID: 0
#
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5Stop command executed successfully
#
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 63, Class ID: 0
# X2-X1: 10, Class ID: 0
# X2-X1: 21, Class ID: 0
# CENTERPOINTS Stop command executed successfully{0: [212], 1: []}
#
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 63, Class ID: 0
# X2-X1: 10, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 63, Class ID: 0
# X2-X1: 10, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 11, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 10, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 62, Class ID: 0
# X2-X1: 10, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 63, Class ID: 0
# X2-X1: 11, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 62, Class ID: 0
# X2-X1: 10, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 62, Class ID: 0
# X2-X1: 10, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 10, Class ID: 0
# No objects detected. Stopping robot.
# Stop command executed successfully
# Motors set successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 11, Class ID: 0
# X2-X1: 20, Class ID: 0
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# X2-X1: 62, Class ID: 0
# X2-X1: 11, Class ID: 0
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25X2-X1: 63, Class ID: 0
#
# Left Speed:X2-X1: 11, Class ID: 0 0.2
#
# X2-X1: 22, Class ID: 0Right Speed:
#  0.1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 61, Class ID: 0
# X2-X1: 10, Class ID: 0
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Stop command executed successfullyDegrees:
#  0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 62, Class ID: 0
# X2-X1: 11, Class ID: 0
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Stop command executed successfully
# Motors set successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°X2-X1: 62, Class ID: 0
#
# Degrees:X2-X1: 11, Class ID: 0
# 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Stop command executed successfully
# Motors set successfully
# Stop command executed successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 20, Class ID: 0
# CENTERPOINTS {0: [213], 1: []}
# AVG_CENTER 213.0
# Average Center: 213.0, Horizontal Angle: 72.14°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# X2-X1: 21, Class ID: 0
# CENTERPOINTS {0: [212], 1: []}
# AVG_CENTER 212.0
# Average Center: 212.0, Horizontal Angle: 71.43°
# Degrees: 0.5
# 0.25
# Left Speed: 0.2
# Right Speed: 0.1
# Motors set successfully
# Stop command executed successfully

# %%
center_points = {}
center_points[0] = []
center_points[1] = []
center_points[0].append(40)
center_points[0].append(50)
center_points[1].append(-40)
import numpy as np
TARGET_WEIGHT = 0.5
target_point = np.array(center_points[1])*TARGET_WEIGHT
robot_point = np.mean((np.array(center_points[0])*(1-TARGET_WEIGHT))/len(center_points[0]))
angle = (target_point[0] + robot_point)

print(target_point)
print(robot_point)
print(angle)
print(center_points[0])
